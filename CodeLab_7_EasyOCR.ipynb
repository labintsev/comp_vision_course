# %% [markdown]
# # Code Lab 7 - Easy OCR
#
# <img src="https://github.com/JaidedAI/EasyOCR/raw/master/examples/easyocr_framework.jpeg">
#
# Этот ноутбук демонстрирует все возможности оптического распознавания символов (OCR) с использованием библиотеки EasyOCR. Мы рассмотрим различные сценарии использования, визуализацию результатов и практические примеры.
#
# ## План работы:
# - Распознавание текста на изображениях (русский + английский)
# - Визуализация bounding boxes
# - Пакетная обработка
# - Работа с разными типами изображений
# - Экспорт результатов

# %% [markdown]
# ## 1. Установка зависимостей
#
# Выполните установку необходимых библиотек:

# %%
! pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /home/andrej/miniconda3/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: torch in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (2.10.0)
# Requirement already satisfied: torchvision>=0.5 in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (0.25.0)
# Requirement already satisfied: opencv-python-headless in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scipy in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (1.17.0)
# Requirement already satisfied: numpy in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (2.4.1)
# Requirement already satisfied: Pillow in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (12.1.0)
# Requirement already satisfied: scikit-image in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: python-bidi in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: PyYAML in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in /home/andrej/miniconda3/lib/python3.13/site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: filelock in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (3.6.1)
# Requirement already satisfied: jinja2 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/andrej/miniconda3/lib/python3.13/site-packages (from torch->easyocr) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/andrej/miniconda3/lib/python3.13/site-packages (from cuda-bindings==12.9.4->torch->easyocr) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/andrej/miniconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andrej/miniconda3/lib/python3.13/site-packages (from jinja2->torch->easyocr) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/andrej/miniconda3/lib/python3.13/site-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/andrej/miniconda3/lib/python3.13/site-packages (from scikit-image->easyocr) (2026.2.24)
# Requirement already satisfied: packaging>=21 in /home/andrej/miniconda3/lib/python3.13/site-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/andrej/miniconda3/lib/python3.13/site-packages (from scikit-image->easyocr) (0.4)

# %% [markdown]
# ## 2. Импорт библиотек

# %%
import os
import sys
import time
import json
from pathlib import Path
from datetime import datetime
from typing import List, Dict, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

import cv2
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import easyocr

# Настройка отображения matplotlib
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 3. Инициализация OCR
#
# Создадим класс для работы с OCR с расширенными возможностями:

# %%
class EasyOCRDemo:
    """Класс для демонстрации возможностей OCR"""
    
    def __init__(self, languages: List[str] = ['ru', 'en'], gpu: bool = False):
        """
        Инициализация OCR-читателя
        
        Args:
            languages: Список языков для распознавания
            gpu: Использовать GPU
        """
        print(f"Инициализация OCR с языками: {languages}")
        print(f"Режим: {'GPU' if gpu else 'CPU'}")
        
        try:
            self.reader = easyocr.Reader(languages, gpu=gpu)
            self.languages = languages
            print("OCR успешно инициализирован")
        except Exception as e:
            print(f"Ошибка: {e}")
            raise
    
    def recognize(self, image_path: str, 
                 detail: int = 1,
                 paragraph: bool = False) -> List:
        """
        Распознавание текста на изображении
        """
        if not os.path.exists(image_path):
            raise FileNotFoundError(f"Файл не найден: {image_path}")
        
        print(f"\n📄 Анализ: {os.path.basename(image_path)}")
        start = time.time()
        
        result = self.reader.readtext(
            image_path,
            detail=detail,
            paragraph=paragraph,
            width_ths=0.7,
            height_ths=0.5
        )
        
        elapsed = time.time() - start
        print(f"✅ Готово за {elapsed:.2f} сек")
        
        return result
    
    def visualize(self, image_path: str, result: List = None,
                  show_confidence: bool = True, figsize=(15, 10)):
        """
        Визуализация результатов распознавания
        """
        if result is None:
            result = self.recognize(image_path)
        
        # Загружаем изображение
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Создаем фигуру
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
        
        # Оригинальное изображение
        ax1.imshow(img)
        ax1.set_title('Оригинальное изображение')
        ax1.axis('off')
        
        # Изображение с разметкой
        ax2.imshow(img)
        ax2.set_title(f'Распознано объектов: {len(result)}')
        
        # Цвета для разных уровней уверенности
        colors = {'high': 'green', 'medium': 'orange', 'low': 'red'}
        
        for detection in result:
            points = detection[0]
            text = detection[1]
            conf = detection[2]
            
            # Определяем цвет
            if conf > 0.8:
                color = colors['high']
            elif conf > 0.5:
                color = colors['medium']
            else:
                color = colors['low']
            
            # Рисуем bounding box
            polygon = plt.Polygon(points, fill=False, 
                                 edgecolor=color, linewidth=2)
            ax2.add_patch(polygon)
            
            # Добавляем текст
            x, y = points[0]
            if show_confidence:
                label = f"{text} ({conf:.2f})"
            else:
                label = text
            
            ax2.text(x, y-5, label, fontsize=8,
                    bbox=dict(boxstyle='round', facecolor=color, alpha=0.7))
        
        ax2.axis('off')
        plt.tight_layout()
        plt.show()
        
        return result
    
    def get_text(self, result: List, min_confidence: float = 0.0) -> str:
        """
        Извлечение текста из результатов
        """
        texts = []
        for detection in result:
            if detection[2] >= min_confidence:
                texts.append(detection[1])
        return '\n'.join(texts)
    
    def save_results(self, result: List, output_path: str):
        """
        Сохранение результатов в JSON
        """
        serializable = []
        for item in result:
            serializable.append({
                'bbox': [[float(x) for x in point] for point in item[0]],
                'text': item[1],
                'confidence': float(item[2])
            })
        
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(serializable, f, ensure_ascii=False, indent=2)
        
        print(f"💾 Результаты сохранены в {output_path}")

# Создаем экземпляр
ocr = EasyOCRDemo(languages=['ru', 'en'], gpu=True)
# Out:
# Инициализация OCR с языками: ['ru', 'en']
# Режим: GPU
# OCR успешно инициализирован

# %% [markdown]
# ## 4. Загрузка тестовых изображений

# %%
test_images = ['data/test1.png', 'data/test2.png', 'data/test3.png']

# %% [markdown]
# ## 5. Базовое распознавание
#
# Продемонстрируем распознавание текста на простом изображении:

# %%
# Выбираем первое тестовое изображение
image_path = test_images[0]
print(f"Изображение: {image_path}")

# Выполняем распознавание
result = ocr.recognize(image_path)

# Выводим результаты
print("\n📝 Распознанный текст:")
print(ocr.get_text(result))

# Визуализируем
ocr.visualize(image_path, result)
# Out:
# Изображение: data/test1.png
#
# 📄 Анализ: test1.png
# ✅ Готово за 0.03 сек
#
# 📝 Распознанный текст:
# Привет, мир!
# Hello, world!
# [([[np.int32(48), np.int32(54)],
#    [np.int32(260), np.int32(54)],
#    [np.int32(260), np.int32(86)],
#    [np.int32(48), np.int32(86)]],
#   'Привет, мир!',
#   np.float64(0.9896534383982927)),
#  ([[np.int32(48), np.int32(81)],
#    [np.int32(245), np.int32(81)],
#    [np.int32(245), np.int32(119)],
#    [np.int32(48), np.int32(119)]],
#   'Hello, world!',
#   np.float64(0.9711779061477865))]

# %% [markdown]
# ## 6. Анализ уверенности распознавания
#
# Посмотрим на уровень уверенности для каждого распознанного элемента:

# %%
def analyze_confidence(result):
    """Анализ уверенности распознавания"""
    confidences = [item[2] for item in result]
    
    if not confidences:
        print("Нет распознанных элементов")
        return
    
    print(f"Статистика уверенности:")
    print(f"  Средняя: {np.mean(confidences):.2%}")
    print(f"  Мин: {np.min(confidences):.2%}")
    print(f"  Макс: {np.max(confidences):.2%}")
    
    # Гистограмма распределения
    plt.figure(figsize=(10, 4))
    plt.hist(confidences, bins=20, edgecolor='black', alpha=0.7)
    plt.xlabel('Уверенность')
    plt.ylabel('Количество')
    plt.title('Распределение уверенности распознавания')
    plt.grid(True, alpha=0.3)
    plt.show()
    
    # Таблица результатов
    print("\nДетальные результаты:")
    for i, (bbox, text, conf) in enumerate(result, 1):
        print(f"{i:2}. {text:30} {conf:.2%}")

analyze_confidence(result)
# Out:
# Статистика уверенности:
#   Средняя: 98.04%
#   Мин: 97.12%
#   Макс: 98.97%
# Детальные результаты:
#  1. Привет, мир!                   98.97%
#  2. Hello, world!                  97.12%

# %% [markdown]
# ## 7. Фильтрация по уверенности
#
# Можно отфильтровать результаты с низкой уверенностью:

# %%
thresholds = [0.0, 0.5, 0.8, 0.9]

for thresh in thresholds:
    filtered_text = ocr.get_text(result, min_confidence=thresh)
    print(f"\nУверенность >= {thresh:.0%}:")
    if filtered_text:
        print(filtered_text)
    else:
        print("  Нет результатов")
# Out:
# Уверенность >= 0%:
# Привет, мир!
# Hello, world!
#
# Уверенность >= 50%:
# Привет, мир!
# Hello, world!
#
# Уверенность >= 80%:
# Привет, мир!
# Hello, world!
#
# Уверенность >= 90%:
# Привет, мир!
# Hello, world!

# %% [markdown]
# ## 8. Пакетная обработка
#
# Обработаем все тестовые изображения одновременно:

# %%
def batch_process(image_list):
    """Пакетная обработка изображений"""
    results = {}
    
    for img_path in image_list:
        print(f"\n{'='*50}")
        result = ocr.recognize(img_path)
        results[img_path] = result
        
        # Сохраняем результаты
        json_path = img_path.replace('.png', '_result.json')
        ocr.save_results(result, json_path)
    
    return results

batch_results = batch_process(test_images)
# Out:
# ==================================================
#
# 📄 Анализ: test1.png
# ✅ Готово за 0.03 сек
# 💾 Результаты сохранены в data/test1_result.json
#
# ==================================================
#
# 📄 Анализ: test2.png
# ✅ Готово за 0.03 сек
# 💾 Результаты сохранены в data/test2_result.json
#
# ==================================================
#
# 📄 Анализ: test3.png
# ✅ Готово за 0.03 сек
# 💾 Результаты сохранены в data/test3_result.json

# %% [markdown]
# ## 9. Работа с реальными изображениями
#
# Загрузим и обработаем реальное изображение. Если у вас есть файл с изображением, укажите его путь:

# %%
# Укажите путь к вашему изображению или используйте тестовое
real_image = 'data/document.jpg'  # Замените на свой путь

if os.path.exists(real_image):
    print(f"Обработка: {real_image}")
    result_real = ocr.recognize(real_image)
    ocr.visualize(real_image, result_real)
    
    print("\n📝 Извлеченный текст:")
    print(ocr.get_text(result_real))
else:
    print("⚠️ Файл не найден. Используйте тестовое изображение.")
# Out:
# Обработка: data/document.jpg
#
# 📄 Анализ: document.jpg
# ✅ Готово за 0.12 сек
# 📝 Извлеченный текст:
# ДОГОВОР Ngl23
# Москва
# 01.01.2024
# ООО "Технолоджи'
# в лице директора Иванова И.И
# и ООО
# Поставщик
# в лице директора Петрова П П:
# заключили настоящий договор
# нижеследующем:
# 1. ПРЕДМЕТ ДОГОВОРА
# 1.1. Поставщик обязуется поставить товар.
# 1.2 Сумма договора: 1 500 000 рублей_
# Подписи сторон:
# Иванов И И:
# Петров П П:

# %% [markdown]
# ## 10. Экспорт в текст

# %%
def export_results(result, base_name):
    """Экспорт в разные форматы"""
    
    # TXT (только текст)
    with open(f"{base_name}.txt", 'w', encoding='utf-8') as f:
        f.write(ocr.get_text(result))
    


# Экспортируем результаты для первого изображения
export_results(result, "data/ocr_results")

# %% [markdown]
# ## 11. Анализ производительности
#
# Измерим скорость работы OCR на разных изображениях:

# %%
def benchmark_ocr(image_paths, iterations=3):
    """Тестирование производительности"""
    
    results = []
    
    for img_path in image_paths:
        times = []
        file_size = os.path.getsize(img_path) / 1024  # KB
        
        for i in range(iterations):
            start = time.time()
            result = ocr.recognize(img_path)
            elapsed = time.time() - start
            times.append(elapsed)
        
        results.append({
            'file': os.path.basename(img_path),
            'size_kb': file_size,
            'objects': len(result),
            'avg_time': np.mean(times),
            'std_time': np.std(times)
        })
    
    # Визуализация
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Время обработки
    files = [r['file'] for r in results]
    times = [r['avg_time'] for r in results]
    
    ax1.bar(files, times)
    ax1.set_ylabel('Время (сек)')
    ax1.set_title('Среднее время обработки')
    ax1.tick_params(axis='x', rotation=45)
    
    # Зависимость времени от размера файла
    sizes = [r['size_kb'] for r in results]
    ax2.scatter(sizes, times, s=100)
    ax2.set_xlabel('Размер файла (KB)')
    ax2.set_ylabel('Время (сек)')
    ax2.set_title('Зависимость времени от размера')
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    return results

benchmark = benchmark_ocr(test_images)
print("\n Результаты бенчмарка:")
for r in benchmark:
    print(f"{r['file']}: {r['avg_time']:.2f}±{r['std_time']:.2f} сек ({r['objects']} объектов)")
# Out:
# 📄 Анализ: test1.png
# ✅ Готово за 0.03 сек
#
# 📄 Анализ: test1.png
# ✅ Готово за 0.02 сек
#
# 📄 Анализ: test1.png
# ✅ Готово за 0.02 сек
#
# 📄 Анализ: test2.png
# ✅ Готово за 0.03 сек
#
# 📄 Анализ: test2.png
# ✅ Готово за 0.03 сек
#
# 📄 Анализ: test2.png
# ✅ Готово за 0.03 сек
#
# 📄 Анализ: test3.png
# ✅ Готово за 0.03 сек
#
# 📄 Анализ: test3.png
# ✅ Готово за 0.03 сек
#
# 📄 Анализ: test3.png
# ✅ Готово за 0.03 сек
#  Результаты бенчмарка:
# test1.png: 0.03±0.00 сек (2 объектов)
# test2.png: 0.03±0.00 сек (3 объектов)
# test3.png: 0.03±0.00 сек (3 объектов)

# %% [markdown]
# ## Задание !!!
#
# Реализовать метрику точности распознавания OCR и проанализировать не менее 3 разных изображение!
#
# ### Полезные ссылки:
# - [Документация EasyOCR](https://www.jaided.ai/easyocr/)
